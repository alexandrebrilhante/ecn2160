# %% [markdown]
# ## Installer R
#
# https://www.r-project.org/

# %% [markdown]
# ## Installer Jupyter
#
# http://jupyter.org/

# %% [markdown]
# ## Installer IRKernel
#
# https://irkernel.github.io/

# %% [markdown]
# #### Sur un terminal: jupyter notebook
#
# Un notebook comme celui-ci s'ouvrira sur votre fureteur.

# %% [markdown]
# ## Alternative: installer RStudio
#
# https://www.rstudio.com/

# %% [markdown]
# ## Opérations de base

# %%
x <- 345

x
# Out:
# [1] 345

# %%
log_x <- log2(x)

log_x
# Out:
# [1] 8.430453

# %%
y <- 45

x-y
# Out:
# [1] 300

# %%
z <- 300

if (x-y == z) {
    return(TRUE)
} else {
    return(FALSE)
}
# Out:
# [1] TRUE

# %%
z <- x-x

z
# Out:
# [1] 0

# %%
a <- 24
b <- 3

mult <- function(a, b) {
    result <- 0
    for (i in 1:b) {
        result <- result+a
    }
    return(result)
}

mult(a, b)
# Out:
# [1] 72

# %%
a*b
# Out:
# [1] 72

# %% [markdown]
# ## Série chronologique

# %%
# On génère 12 valeurs aléatoires.

input <- rnorm(12)

# %%
input
# Out:
#  [1]  0.6326846 -0.1864218  1.0188797 -0.2973041 -0.4839654 -0.3332725
#  [7]  1.5138834  0.2257110 -1.2573609 -1.4050055 -0.9730891  0.4641290

# %%
# On convertit nos valeurs en série chronologique.

input <- ts(input, start = c(2018, 1), frequency = 12)

# %%
input
# Out:
#             Jan        Feb        Mar        Apr        May        Jun
# 2018  0.6326846 -0.1864218  1.0188797 -0.2973041 -0.4839654 -0.3332725
#             Jul        Aug        Sep        Oct        Nov        Dec
# 2018  1.5138834  0.2257110 -1.2573609 -1.4050055 -0.9730891  0.4641290

# %%
plot.ts(input)
# Out:
# plot without title

# %% [markdown]
# ## Nuage de point

# %%
# On génère 10 points aléatoires.

x <- rnorm(10)
y <- rnorm(10)

# %%
plot(x, y)
# Out:
# plot without title

# %% [markdown]
# ## Régression linéaire

# %%
# Création de données.
set.seed(123)

x <- 1:20 + rnorm(100, sd = 3)
z <- 1:20/4 + rnorm(100, sd = 2)
y <- -2*x + x*z/5 + 3 + rnorm(100, sd = 4)

# On créé un dataframe avec nos données.
dat <- data.frame(x = x, y = y, z = z)

head(dat)
# Out:
#   x          y          z
# 1 -0.6814269  13.317660 -1.1708131
# 2  1.3094675   5.896216  1.0137674
# 3  7.6761249 -13.018866  0.2566162
# 4  4.2115252  -2.993443  0.3049148
# 5  5.3878632 -10.136997 -0.6532371
# 6 11.1451950 -18.052556  1.4099446

# %% [markdown]
# #### Corrélation

# %%
cor(dat$x, dat$y)
# Out:
# [1] -0.7894995

# %% [markdown]
# #### Régression linéaire simple

# %%
fit <- lm(dat$y ~ dat$x)

fit
# Out:
# Call:
# lm(formula = dat$y ~ dat$x)
#
# Coefficients:
# (Intercept)        dat$x
#       2.365       -1.256

# %% [markdown]
# #### Cela veut donc dire que y = 2.365 - 1.256x.

# %%
summary(fit)
# Out:
# Call:
# lm(formula = dat$y ~ dat$x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.9923  -4.9756  -0.0181   3.9530  19.4712
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.36489    1.24670   1.897   0.0608 .
# dat$x       -1.25632    0.09866 -12.734   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.52 on 98 degrees of freedom
# Multiple R-squared:  0.6233,	Adjusted R-squared:  0.6195
# F-statistic: 162.2 on 1 and 98 DF,  p-value: < 2.2e-16

# %%
plot(fit)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# #### Régression linéaire multiple

# %%
fit <- lm(dat$z ~ dat$x + dat$y)

fit
# Out:
# Call:
# lm(formula = dat$z ~ dat$x + dat$y)
#
# Coefficients:
# (Intercept)        dat$x        dat$y
#     -0.1735       0.4523       0.2049

# %% [markdown]
# #### Cela veut donc dire que z = -0.1735 + 0.4523x + 0.2049y.

# %%
summary(fit)
# Out:
# Call:
# lm(formula = dat$z ~ dat$x + dat$y)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.1060 -0.8619 -0.1232  1.0091  5.6455
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.17355    0.30721  -0.565    0.573
# dat$x        0.45229    0.03890  11.626  < 2e-16 ***
# dat$y        0.20491    0.02445   8.382 4.12e-13 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.578 on 97 degrees of freedom
# Multiple R-squared:  0.5852,	Adjusted R-squared:  0.5767
# F-statistic: 68.43 on 2 and 97 DF,  p-value: < 2.2e-16

# %%
plot(fit)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
